# %% [markdown]
# <a href="https://colab.research.google.com/github/LuminaX-alt/Admin/blob/main/Techie_Voice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
# Import necessary libraries
from gtts import gTTS
from IPython.display import Audio, display

# Luminax Alt Introduction Text
intro_text = """
Hello World! Myself, Luminax Alt.
I am your AI Doctor developed by Mr. Dev and Prathamesh,
students from Dayananda Sagar University.
My masters are currently developing me further.

Currently, I am consulting with:
- Diabetes Prediction
- X-ray and Blood Cell Classification
- Skin Cancer Detection
- Brain Tumor Detection

In the future, I aim to become one of the Med Giants!
"""

# Print the message
print(intro_text)

# Convert the text to speech
tts = gTTS(text=intro_text, lang='en')
tts.save("luminax_intro.mp3")

# Play the audio
display(Audio("luminax_intro.mp3", autoplay=True))
# Out:
# Hello World! Myself, Luminax Alt.
# I am your AI Doctor developed by Mr. Dev and Prathamesh,
# students from Dayananda Sagar University.
# My masters are currently developing me further.
#
# Currently, I am consulting with:
# - Diabetes Prediction
# - X-ray and Blood Cell Classification
# - Skin Cancer Detection
# - Brain Tumor Detection
#
# In the future, I aim to become one of the Med Giants!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install gTTS

# %%
# Import necessary libraries
from gtts import gTTS
from IPython.display import Audio

# Luminax Alt Introduction Text
intro_text = """
Hello World! Myself, Luminax Alt.
I am your AI Doctor developed by Mr. Dev and Prathamesh,
students from Dayananda Sagar University.
My masters are currently developing me further.

Currently, I am consulting with:
- Diabetes Prediction
- X-ray and Blood Cell Classification
- Skin Cancer Detection
- Brain Tumor Detection

In the future, I aim to become one of the Med Giants!
"""

# Convert text to speech
tts = gTTS(text=intro_text, lang='en')

# Save the speech audio to a file
tts.save("/content/luminax_intro.mp3")

# Play the saved audio
Audio("/content/luminax_intro.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
